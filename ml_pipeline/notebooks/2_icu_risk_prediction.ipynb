# %% [markdown]
# # ICU Risk Prediction
#
# Review feature engineering choices and evaluate the deterioration classifier.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
data = pd.read_csv(root / 'data' / 'raw' / 'vitals.csv').merge(
    pd.read_csv(root / 'data' / 'raw' / 'labs.csv'),
    on='patient_id'
)
data[['heart_rate', 'respiratory_rate', 'oxygen_saturation', 'lactate', 'icu_event']]

# %% [markdown]
# # Imaging Analysis
#
# Prototype image-feature extraction for triage labeling and confidence calibration.

# %%
from pathlib import Path

root = Path.cwd().parents[0]
sorted((root / 'data' / 'raw' / 'imaging').iterdir())

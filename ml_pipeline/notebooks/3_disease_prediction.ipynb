# %% [markdown]
# # Disease Prediction
#
# Benchmark boosted tree alternatives for chronic disease and sepsis watch scoring.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
labs = pd.read_csv(root / 'data' / 'raw' / 'labs.csv')
labs[['glucose', 'ldl', 'troponin', 'hba1c', 'disease_risk_label']].head()

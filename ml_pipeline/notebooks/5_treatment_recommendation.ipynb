# %% [markdown]
# # Treatment Recommendation
#
# Inspect the policy dataset used to map risk factors to recommended intervention classes.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
vitals = pd.read_csv(root / 'data' / 'raw' / 'vitals.csv')
vitals[['patient_id', 'icu_event', 'treatment_class']].head()

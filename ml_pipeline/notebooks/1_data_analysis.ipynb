# %% [markdown]
# # Data Analysis
#
# Initial exploration of vitals and laboratory distributions for the sample patient cohort.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0]
vitals = pd.read_csv(root / 'data' / 'raw' / 'vitals.csv')
labs = pd.read_csv(root / 'data' / 'raw' / 'labs.csv')
vitals.merge(labs, on='patient_id').describe(include='all')
